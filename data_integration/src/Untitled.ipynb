# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/trr_trr_refresh.csv")
# Out:
# /Users/xingbangliu/.local/share/virtualenvs/The-Dapper-Squirrels-zr-O-A32/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(5)
# Out:
#      id  beat block direction           street                 location  \
# 0  7656   732  70XX     South      Emerald Ave  Residence Porch/Hallway
# 1  7657  1014  16XX     South        Avers Ave          Vacant Property
# 2  7658  1021  14XX     South        Homan Ave  Residence Porch/Hallway
# 3  7659     0  14XX     South       Homan Blvd  Residence Porch/Hallway
# 4  7660  2525  22XX     North  Springfield Ave                Apartment
#
#              trr_datetime indoor_or_outdoor lighting_condition  \
# 0  2005-04-10 17:40:00+00           Outdoor           DAYLIGHT
# 1  2005-04-10 18:15:00+00           Outdoor           DAYLIGHT
# 2  2005-04-10 20:30:00+00            Indoor    GOOD ARTIFICIAL
# 3  2005-04-10 20:30:00+00            Indoor    GOOD ARTIFICIAL
# 4  2005-04-10 21:35:00+00               NaN                NaN
#
#   weather_condition  ...  subject_gender  subject_race  officer_id  \
# 0             CLEAR  ...               F         BLACK     26342.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67019 entries, 0 to 67018
# Data columns (total 42 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                67019 non-null  int64
#  1   beat                              67019 non-null  int64
#  2   block                             67019 non-null  object
#  3   direction                         66969 non-null  object
#  4   street                            67019 non-null  object
#  5   location                          67019 non-null  object
#  6   trr_datetime                      67019 non-null  object
#  7   indoor_or_outdoor                 63414 non-null  object
#  8   lighting_condition                63381 non-null  object
#  9   weather_condition                 63220 non-null  object
#  10  notify_OEMC                       67019 non-null  bool
# ...

# %%
df['subject_armed'] = df['subject_armed'].astype(object)

df['subject_armed']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 67014    False
# 67015    False
# 67016    False
# 67017    False
# 67018    False
# Name: subject_armed, Length: 67019, dtype: object

# %%
df['firearm_reloaded'] = df['firearm_reloaded'].astype(bool)
df['sight_used'] = df['sight_used'].astype(bool)
df['officer_appointed_date'] = pd.to_datetime(df['officer_appointed_date'])
df['officer_birth_year'] = df['officer_birth_year'].astype(int)
df['status_datetime'] = pd.to_datetime(df['status_datetime'])

# %%
df['trr_datetime'] = pd.to_datetime(df['trr_datetime'], utc=True)
df['beat'] = df['beat'].astype(int)
# df[df['officer_appointed_date'] == 'REDACTED' ] = df[df['officer_appointed_date'] == 'REDACTED' ].fillna(0)
# df[df['officer_appointed_date'] != 'REDACTED' ] = pd.to_datetime(df[df['officer_appointed_date'] != 'REDACTED' ], utc=True)
#df[df['officer_appointed_date'] != 'REDACTED' ]['officer_appointed_date'] =pd.to_datetime(df[df['officer_appointed_date'] != 'REDACTED' ]['officer_appointed_date'])
df['officer_birth_year'] = df['officer_birth_year'].fillna(0.0).astype(int)
df['officer_age'] = df['officer_age'].astype(int)
df['officer_on_duty'] = df['officer_on_duty'].astype(bool)
df['officer_injured'] = df['officer_injured'].astype(bool)
df['officer_in_uniform'] = df['officer_in_uniform'].astype(bool)
df['subject_birth_year'] = df['subject_birth_year'].astype(int)
df['subject_age'] = df['subject_age'].astype(int)
df['subject_armed'] = df['subject_armed'].astype(bool)
df['subject_injured'] = df['subject_injured'].astype(bool)
df['subject_alleged_injury'] = df['subject_alleged_injury'].astype(bool)
df['notify_oemc'] = df['notify_oemc'].astype(bool)
df['notify_district_sergeant'] = df['notify_district_sergeant'].astype(bool)
df['notify_op_command'] = df['notify_op_command'].astype(bool)
df['notify_det_division'] = df['notify_det_division'].astype(bool)
df['trr_created'] = pd.to_datetime(df['trr_created'], utc=True)

# %%
df[''] = df[''].astype()

# %%
appoint_date = df['officer_appointed_date'].to_numpy()
for i in range(len(appoint_date)):
    day = df['officer_appointed_date'][i]
    if day == 'REDACTED':
        appoint_date[i] = np.nan  
    elif len(day) == 8:
        if int(day[0:2])+2000 > 2021:
            appoint_date[i] = (19+day)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-73d2326c95f2> in <module>
# ----> 1 correct_type(df,type_correction)
#
# <ipython-input-53-1f9e89fd3b5a> in correct_type(df, corrections)
#       1 def correct_type(df, corrections):
#       2     for correction in corrections:
# ----> 3         df[correction[0]] = df[correction[0]].astype(correction[1])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
# ...

# %%
df['trr_datetime']
# Out:
# 0        2005-04-10 17:40:00+00
# 1        2005-04-10 18:15:00+00
# 2        2005-04-10 20:30:00+00
# 3        2005-04-10 20:30:00+00
# 4        2005-04-10 21:35:00+00
#                   ...
# 67014    2005-04-10 11:15:00+00
# 67015    2005-04-10 11:15:00+00
# 67016    2005-04-10 13:15:00+00
# 67017    2005-04-10 17:50:00+00
# 67018    2005-04-13 10:07:00+00
# Name: trr_datetime, Length: 67019, dtype: object
